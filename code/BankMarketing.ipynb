# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/gabriel/myprojects/treinandoanalisedados/date/bank_full.csv', sep=';')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df['marital'].value_counts(normalize=True)
# Out:
# married     0.601933
# single      0.282896
# divorced    0.115171
# Name: marital, dtype: float64

# %%
#qual a porcentagem de divorciados empreendedores
df[(df['marital'] == 'divorced') & (df['job'] == 'entrepreneur')]
# Out:
#        age           job   marital  education default  balance housing loan  \
# 7       42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 94      57  entrepreneur  divorced  secondary      no      -37      no   no
# 222     35  entrepreneur  divorced  secondary      no      -69     yes   no
# 256     59  entrepreneur  divorced  secondary      no      901     yes   no
# 273     56  entrepreneur  divorced  secondary      no      155      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 42443   38  entrepreneur  divorced  secondary      no     1190     yes   no
# 42597   50  entrepreneur  divorced   tertiary      no      315      no   no
# 43445   51  entrepreneur  divorced   tertiary      no     2109      no   no
# 44130   50  entrepreneur  divorced   tertiary      no      315      no   no
# 44969   51  entrepreneur  divorced   tertiary      no      315      no   no
#
# ...

# %%
divorciados= df[(df['marital'] == 'divorced')]
empreendedores_divorciados = divorciados[(divorciados['job'] == 'entrepreneur')]
porcentagem_empreendedores_divorciados = (len(empreendedores_divorciados) / len(divorciados)) * 100
print(f" Divorciados e empreendedores: {porcentagem_empreendedores_divorciados:.2f}%")
# Out:
#  Divorciados e empreendedores: 3.44%

# %%
estudantes_divorciados = divorciados[(divorciados['job'] == 'student')]
porcentagem_estudantes_divorciados = (len(estudantes_divorciados) / len(divorciados)) * 100
print(f" Estudantes e divorciados: {porcentagem_estudantes_divorciados:.2f}%")
# Out:
#  Estudantes e divorciados: 0.12%

# %%
df['balance_bins'] = pd.qcut(df['balance'], q=[0.8, 0.9, 1], labels=['gold', 'premium'])
df['balance_bins'].value_counts()
# Out:
# gold       4528
# premium    4521
# Name: balance_bins, dtype: int64

# %%
df.loc[df['balance_bins'] == 'gold']
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 40      44      services  divorced  secondary      no     2586     yes   no
# 74      43    technician   married  secondary      no     1937     yes   no
# 83      59        admin.   married  secondary      no     2343     yes   no
# 129     55      services   married  secondary      no     2476     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45172   30    technician    single   tertiary      no     2325      no   no
# 45175   38  entrepreneur    single  secondary      no     2543      no   no
# 45180   66       retired   married  secondary      no     3409      no   no
# 45204   73       retired   married  secondary      no     2850      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.loc[df['balance_bins'] == 'premium']
# Out:
#        age          job   marital  education default  balance housing loan  \
# 34      51   management   married   tertiary      no    10635     yes   no
# 65      51   management   married   tertiary      no     6530     yes   no
# 69      35  blue-collar    single  secondary      no    12223     yes  yes
# 70      57  blue-collar   married  secondary      no     5935     yes  yes
# 186     40     services  divorced    unknown      no     4384     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 45164   35     services   married   tertiary      no     4655      no   no
# 45181   46  blue-collar   married  secondary      no     6879      no   no
# 45185   60     services   married   tertiary      no     4256     yes   no
# 45191   75      retired  divorced   tertiary      no     3810     yes   no
# 45208   72      retired   married  secondary      no     5715      no   no
#
# ...

# %%
# Verifique como a tabela cruzada da população se diferencia do grupo Premium
df.groupby(['balance_bins', 'marital']).size().unstack()
# Out:
# marital       divorced  married  single
# balance_bins
# gold               493     2835    1200
# premium            437     2886    1198

# %%
# Verifique como a tabela cruzada da população se diferencia do grupo Premium
df.pivot_table(index='balance_bins', columns=['marital'], aggfunc='size')
# Out:
# marital       divorced  married  single
# balance_bins
# gold               493     2835    1200
# premium            437     2886    1198

# %%
print(len(df[df['marital'] == 'divorced']))
print(len(df[df['marital'] == 'married']))
print(len(df[df['marital'] == 'single']))
print(len(df['marital']))
# Out:
# 5207
# 27214
# 12790
# 45211

# %%
#CLientes com os 10 maiores saldos
balance_10 = df.sort_values(by='balance', ascending=False).head(10)
balance_10
# Out:
#        age           job   marital  education default  balance housing loan  \
# 39989   51    management    single   tertiary      no   102127      no   no
# 26227   59    management   married   tertiary      no    98417      no   no
# 43393   84       retired   married  secondary      no    81204      no   no
# 42558   84       retired   married  secondary      no    81204      no   no
# 41693   60       retired   married    primary      no    71188      no   no
# 19785   56    management  divorced   tertiary      no    66721      no   no
# 21192   52   blue-collar   married    primary      no    66653      no   no
# 19420   59        admin.   married    unknown      no    64343      no   no
# 41374   32  entrepreneur    single   tertiary      no    59649      no   no
# 12926   56   blue-collar   married  secondary      no    58932      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
#Clientes com os 10 menores saldos
balance_menos_10 = df['balance'].nsmallest(10).unique()
balance_menos_10
# Out:
# array([-8019, -6847, -4057, -3372, -3313, -3058, -2827, -2712, -2604,
#        -2282])

# %%
columns_show = ['age', 'job', 'marital', 'education', 'default', 'loan', 'duration']
more_10 = balance_10[columns_show]
more_10
# Out:
#        age           job   marital  education default loan  duration
# 39989   51    management    single   tertiary      no   no        90
# 26227   59    management   married   tertiary      no   no       145
# 43393   84       retired   married  secondary      no   no       390
# 42558   84       retired   married  secondary      no   no       679
# 41693   60       retired   married    primary      no   no       205
# 19785   56    management  divorced   tertiary      no   no       442
# 21192   52   blue-collar   married    primary      no   no       109
# 19420   59        admin.   married    unknown      no   no        45
# 41374   32  entrepreneur    single   tertiary      no   no        69
# 12926   56   blue-collar   married  secondary      no   no       339

# %%
def highlight_max_min(s):
    is_max = s == s.max()
    is_min = s == s.min()
    return ['color: yellow' if v_max else 'color:red' if v_min else '' for v_max, v_min in zip(is_max, is_min)]

more_10.style.apply(highlight_max_min, subset=['duration'])
# Out:
# <style type="text/css">
# #T_7ffd4_row3_col6 {
#   color: yellow;
# }
# #T_7ffd4_row7_col6 {
#   color: red;
# }
# </style>
# <table id="T_7ffd4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ffd4_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_7ffd4_level0_col1" class="col_heading level0 col1" >job</th>
#       <th id="T_7ffd4_level0_col2" class="col_heading level0 col2" >marital</th>
#       <th id="T_7ffd4_level0_col3" class="col_heading level0 col3" >education</th>
#       <th id="T_7ffd4_level0_col4" class="col_heading level0 col4" >default</th>
#       <th id="T_7ffd4_level0_col5" class="col_heading level0 col5" >loan</th>
#       <th id="T_7ffd4_level0_col6" class="col_heading level0 col6" >duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ffd4_level0_row0" class="row_heading level0 row0" >39989</th>
#       <td id="T_7ffd4_row0_col0" class="data row0 col0" >51</td>
# ...
