# %%
import pandas as pd
import numpy as np

# %%
stud = pd.read_csv("/Users/gabriel/MYprojects/treinandoanalisedados/date/Estudantes.csv", sep=";")
stud.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
#Qual a proporção de dorpous 
stud["Target"].value_counts(normalize=True)  #.value_counts(1)
# Out:
# Graduate    0.499322
# Dropout     0.321203
# Enrolled    0.179476
# Name: Target, dtype: float64

# %%
#Qual a média de Inflação para cada Tipo de Target
stud.groupby("Target")["Inflation rate"].mean()
# Out:
# Target
# Dropout     1.283955
# Enrolled    1.211713
# Graduate    1.197918
# Name: Inflation rate, dtype: float64

# %%
#pivot table = tabela dinâmica
stud.pivot_table(index='Target', columns=['Marital status'], values='Inflation rate', aggfunc=np.mean)
# Out:
# Marital status         1         2     3         4         5      6
# Target
# Dropout         1.282601  1.300559  1.40  1.269048  1.354545  0.875
# Enrolled        1.220694  1.003846  2.55  1.593750 -0.333333  1.400
# Graduate        1.193499  1.216216 -0.80  1.163636  2.181818 -0.300

# %%
stud.pivot_table(index='Target',
                 columns=['Daytime/evening attendance\t', 'Marital status'],
                 values= 'Previous qualification (grade)',
                 aggfunc=np.mean
                )
# Out:
# Daytime/evening attendance	           0                                        \
# Marital status                        1           2      3           4      5
# Target
# Dropout                      128.471774  130.476471    NaN  127.733333  120.0
# Enrolled                     128.863415  133.296000    NaN  135.400000    NaN
# Graduate                     132.313333  131.133784  120.0  138.388235  120.0
#
# Daytime/evening attendance	                  1                                 \
# Marital status                   6           1           2      3           4
# Target
# Dropout                      122.5  131.537736  129.937838  135.0  130.753333
# Enrolled                     133.1  131.172607  129.177778  154.0  137.412500
# Graduate                     133.1  134.495393  130.505405    NaN  126.593750
#
# Daytime/evening attendance
# Marital status                      5      6
# Target
# Dropout                      143.5500  133.1
# ...

# %%
#teste de cores para o dataframe
df = pd.DataFrame({
    'A': [1, -2, 4],
    'B': [-1, 3, -4],
})
def color_positive_negative(val):
    color = 'yellow'if val > 0 else 'red'
    return 'color: %s' % color

styled_df= df.style.applymap(color_positive_negative)
display(styled_df)
# Out:
# <style type="text/css">
# #T_b6366_row0_col0, #T_b6366_row1_col1, #T_b6366_row2_col0 {
#   color: yellow;
# }
# #T_b6366_row0_col1, #T_b6366_row1_col0, #T_b6366_row2_col1 {
#   color: red;
# }
# </style>
# <table id="T_b6366">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6366_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b6366_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6366_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6366_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b6366_row0_col1" class="data row0 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b6366_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6366_row1_col0" class="data row1 col0" >-2</td>
#       <td id="T_b6366_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
# ...

# %%
#destaca o maximo e minimo 
def highlight_max_min(s):
    is_max = s == s.max()
    is_min = s == s.min()
    return ['color: yellow' if v_max else 'color:red' if v_min else '' for v_max, v_min in zip(is_max, is_min)]

styled_df = df.style.apply(highlight_max_min)
display(styled_df)
# Out:
# <style type="text/css">
# #T_16908_row1_col0, #T_16908_row2_col1 {
#   color: red;
# }
# #T_16908_row1_col1, #T_16908_row2_col0 {
#   color: yellow;
# }
# </style>
# <table id="T_16908">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16908_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_16908_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16908_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16908_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_16908_row0_col1" class="data row0 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_16908_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16908_row1_col0" class="data row1 col0" >-2</td>
#       <td id="T_16908_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
# ...

# %%
pivot_df = stud.pivot_table(index='Marital status',
                            columns=['Target'],
                            values= 'Previous qualification (grade)',
                            aggfunc=np.mean
                            )
pivot_df
# Out:
# Target             Dropout    Enrolled    Graduate
# Marital status
# 1               131.216639  131.041111  134.381687
# 2               130.142458  131.157692  130.819595
# 3               135.000000  154.000000  120.000000
# 4               129.890476  136.406250  132.669697
# 5               141.409091  128.700000  128.827273
# 6               127.800000  133.100000  133.100000

# %%
#Destacar os valores maiores e menores de cada coluna. Como é coluna se utilize apply()
def highlight_max_min(data):
    styles = data.copy()
    for col in data.columns: 
        max_val = data[col].max()
        min_val = data[col].min()
        styles[col] = ['background-color: blue' if v == max_val else 'background-color: yellow' 
                       if v == min_val else '' for v in data[col]
                       ]
    return styles

styled_df = pivot_df.style.apply(highlight_max_min, axis = None)
display(styled_df)
# Out:
# <style type="text/css">
# #T_081f8_row0_col2, #T_081f8_row2_col1, #T_081f8_row4_col0 {
#   background-color: blue;
# }
# #T_081f8_row2_col2, #T_081f8_row4_col1, #T_081f8_row5_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_081f8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Target</th>
#       <th id="T_081f8_level0_col0" class="col_heading level0 col0" >Dropout</th>
#       <th id="T_081f8_level0_col1" class="col_heading level0 col1" >Enrolled</th>
#       <th id="T_081f8_level0_col2" class="col_heading level0 col2" >Graduate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Marital status</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_081f8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_081f8_row0_col0" class="data row0 col0" >131.216639</td>
# ...

# %%
stud.agg("mean", axis=0)
# Out:
# /var/folders/s3/0pht2qcx5377_4vjf7n4_ft00000gn/T/ipykernel_19828/2935730057.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   stud.agg("mean", axis=0)
# Marital status                                       1.178571
# Application mode                                    18.669078
# Application order                                    1.727848
# Course                                            8856.642631
# Daytime/evening attendance\t                         0.890823
# Previous qualification                               4.577758
# Previous qualification (grade)                     132.613314
# Nacionality                                          1.873192
# Mother's qualification                              19.561935
# ...

# %%
stud.agg(['sum', 'mean', 'min'])
# Out:
# /var/folders/s3/0pht2qcx5377_4vjf7n4_ft00000gn/T/ipykernel_19828/3937217253.py:1: FutureWarning: ['Target'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   stud.agg(['sum', 'mean', 'min'])
#       Marital status  Application mode  Application order        Course  \
# sum      5214.000000      82592.000000        7644.000000  3.918179e+07
# mean        1.178571         18.669078           1.727848  8.856643e+03
# min         1.000000          1.000000           0.000000  3.300000e+01
#
#       Daytime/evening attendance\t  Previous qualification  \
# sum                    3941.000000            20252.000000
# mean                      0.890823                4.577758
# min                       0.000000                1.000000
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# sum                    586681.300000  8287.000000            86542.000000
# ...

# %%
def amplitude(series):
    return series.max() - series.min()

stud.agg(['sum', 'mean', "min", "max", amplitude])
# Out:
# /var/folders/s3/0pht2qcx5377_4vjf7n4_ft00000gn/T/ipykernel_19828/965376117.py:4: FutureWarning: ['Target'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   stud.agg(['sum', 'mean', "min", "max", amplitude])
#            Marital status  Application mode  Application order        Course  \
# sum           5214.000000      82592.000000        7644.000000  3.918179e+07
# mean             1.178571         18.669078           1.727848  8.856643e+03
# min              1.000000          1.000000           0.000000  3.300000e+01
# max              6.000000         57.000000           9.000000  9.991000e+03
# amplitude        5.000000         56.000000           9.000000  9.958000e+03
#
#            Daytime/evening attendance\t  Previous qualification  \
# sum                         3941.000000            20252.000000
# mean                           0.890823                4.577758
# ...
