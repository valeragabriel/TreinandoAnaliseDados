# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/Users/gabriel/myprojects/treinandoanalisedados/date/dataCorinthians/A - Jogos.csv", quotechar='"', thousands='.', decimal=',')
print(df.head())
# Out:
#    JOGO RESULTADO  CORINTHIANS  GOL COR  GOL VIS      VISITANTE  \
# 0     1         D  CORINTHIANS        0        1    FIGUEIRENSE
# 1     2         E  CORINTHIANS        1        1       BOTAFOGO
# 2     3         V  CORINTHIANS        2        1  INTERNACIONAL
# 3     4         V  CORINTHIANS        3        0          BAHIA
# 4     5         V  CORINTHIANS        2        0      PALMEIRAS
#
#   CIDADE - VISITANTE  UF PAIS  DIA  MES  ANO   HORA DIA-SEMANA  \
# 0      FLORIANÓPOLIS  SC  BRA   18    5   14  16:00        DOM
# 1     RIO DE JANEIRO  RJ  BRA    1    6   14  16:00        DOM
# 2       PORTO ALEGRE  RS  BRA   17    7   14  19:30        QUI
# 3           SALVADOR  BA  BRA   23    7   14  22:00        QUA
# 4          SÃO PAULO  SP  BRA   27    7   14  16:00        DOM
#
#        CAMPEONATO CAPITÃO       TÉCNICO TÉCNICO - VISITANTE  PUBLICO  \
# 0      BRASILEIRO    RALF  MANO MENEZES       GUTO FERREIRA    36123
# ...

# %%
df.head()
# Out:
#    JOGO RESULTADO  CORINTHIANS  GOL COR  GOL VIS      VISITANTE  \
# 0     1         D  CORINTHIANS        0        1    FIGUEIRENSE
# 1     2         E  CORINTHIANS        1        1       BOTAFOGO
# 2     3         V  CORINTHIANS        2        1  INTERNACIONAL
# 3     4         V  CORINTHIANS        3        0          BAHIA
# 4     5         V  CORINTHIANS        2        0      PALMEIRAS
#
#   CIDADE - VISITANTE  UF PAIS  DIA  MES  ANO   HORA DIA-SEMANA  \
# 0      FLORIANÓPOLIS  SC  BRA   18    5   14  16:00        DOM
# 1     RIO DE JANEIRO  RJ  BRA    1    6   14  16:00        DOM
# 2       PORTO ALEGRE  RS  BRA   17    7   14  19:30        QUI
# 3           SALVADOR  BA  BRA   23    7   14  22:00        QUA
# 4          SÃO PAULO  SP  BRA   27    7   14  16:00        DOM
#
#        CAMPEONATO CAPITÃO       TÉCNICO TÉCNICO - VISITANTE  PUBLICO  \
# 0      BRASILEIRO    RALF  MANO MENEZES       GUTO FERREIRA    36123
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   JOGO                     321 non-null    int64
#  1   RESULTADO                321 non-null    object
#  2   CORINTHIANS              321 non-null    object
#  3   GOL COR                  321 non-null    int64
#  4   GOL VIS                  321 non-null    int64
#  5   VISITANTE                321 non-null    object
#  6   CIDADE - VISITANTE       321 non-null    object
#  7   UF                       321 non-null    object
#  8   PAIS                     321 non-null    object
#  9   DIA                      321 non-null    int64
#  10  MES                      321 non-null    int64
#  11  ANO                      321 non-null    int64
#  12  HORA                     321 non-null    object
#  13  DIA-SEMANA               321 non-null    object
# ...

# %%
df.describe().T
# Out:
#                count          mean           std   min        25%         50%  \
# JOGO           321.0  1.610000e+02  9.280894e+01   1.0      81.00      161.00
# GOL COR        321.0  1.579439e+00  1.188781e+00   0.0       1.00        1.00
# GOL VIS        321.0  7.320872e-01  8.196026e-01   0.0       0.00        1.00
# DIA            321.0  1.579439e+01  8.874548e+00   1.0       9.00       16.00
# MES            321.0  6.373832e+00  3.040940e+00   1.0       4.00        7.00
# ANO            321.0  1.866978e+01  2.763036e+00  14.0      16.00       19.00
# PUBLICO        321.0  2.894790e+04  1.421037e+04   0.0   23903.00    32877.00
# RENDA          321.0  1.674300e+06  1.049293e+06   0.0  966124.74  1671129.76
# CAMISA         321.0  1.068536e+00  3.186505e-01   1.0       1.00        1.00
# NUM-GOLS       321.0  2.311526e+00  1.462924e+00   0.0       1.00        2.00
# GOL-SUL        321.0  7.725857e-01  8.185329e-01   0.0       0.00        1.00
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [JOGO, RESULTADO, CORINTHIANS, GOL COR, GOL VIS, VISITANTE, CIDADE - VISITANTE, UF, PAIS, DIA, MES, ANO, HORA, DIA-SEMANA, CAMPEONATO, CAPITÃO, TÉCNICO, TÉCNICO - VISITANTE, PUBLICO, RENDA, CAMISA, SAÍDA DE JOGO, 1 TEMPO, 2 TEMPO, ARTILHEIROS, ARTILHEIROS - VISITANTE, NUM-GOLS, PRIMEIRO GOL, GOL-SUL, GOL-NORTE, GOL VIS-SUL, GOL VIS-NORTE, GOL-1T, GOL-2T, GOL VIS-1T, GOL VIS-2T, ÁRBITRO, UF-ÁRBITRO, VAR]
# Index: []

# %%
df.isnull().all()
# Out:
# JOGO                       False
# RESULTADO                  False
# CORINTHIANS                False
# GOL COR                    False
# GOL VIS                    False
# VISITANTE                  False
# CIDADE - VISITANTE         False
# UF                         False
# PAIS                       False
# DIA                        False
# MES                        False
# ANO                        False
# HORA                       False
# DIA-SEMANA                 False
# CAMPEONATO                 False
# CAPITÃO                    False
# TÉCNICO                    False
# TÉCNICO - VISITANTE        False
# PUBLICO                    False
# RENDA                      False
# CAMISA                     False
# SAÍDA DE JOGO              False
# 1 TEMPO                    False
# 2 TEMPO                    False
# ARTILHEIROS                False
# ARTILHEIROS - VISITANTE    False
# NUM-GOLS                   False
# PRIMEIRO GOL               False
# ...

# %%
series_has_null = df.isnull().any()
series_has_null[series_has_null == True].keys()
# Out:
# Index([], dtype='object')

# %%
list_col_with_null = list(series_has_null[series_has_null == True].keys())
df[list_col_with_null].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Empty DataFrame

# %%
#Quantidades de jogos por ano 
df['JOGO'].groupby(df['VISITANTE']).count()
# Out:
# VISITANTE
# ALWAYS READY          1
# AMÉRICA (MG)          6
# ARGENTINOS JUNIORS    1
# ATHLETICO             8
# ATLÉTICO (GO)         6
#                      ..
# UNIVERSITARIO         1
# VASCO DA GAMA         6
# VITÓRIA               4
# XV DE PIRACICABA      1
# ÁGUA SANTA            1
# Name: JOGO, Length: 88, dtype: int64
